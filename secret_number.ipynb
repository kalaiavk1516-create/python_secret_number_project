# %% [markdown]
# <a href="https://colab.research.google.com/github/kalaiavk1516-create/python_secret_number_project/blob/main/secret_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("kalai")
# Out:
# kalai

# %%
import random

secret_number = random.randint(1, 10)
attempts = 3

while attempts > 0:
    guess = int(input("Guess the number (between 1 and 10):"))
    if guess < 1 or guess > 10:
        print("Your guess is out of range. Please guess a number between 1 and 10.")
        continue
    attempts -= 1
    if guess == secret_number:
        print("Congratulations! You guessed the correct number.")
        break
    elif guess > secret_number:
        print("Your guess is too high. Try again.")
    else:
        print("Your guess is too low. Try again.")
else:
    print("Better luck next time!")
# Out:
# Guess the number (between 1 and 10):7
# Your guess is too high. Try again.
# Guess the number (between 1 and 10):6
# Your guess is too high. Try again.
# Guess the number (between 1 and 10):8
# Your guess is too high. Try again.
# Better luck next time!

# %%
number = int(input("enter the number for which you want the multiplication table:"))

for i in range(1, 11):
    result = number * i
    print(number,"x", i, "=",
result)
# Out:
# enter the number for which you want the multiplication table:5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
def calculate_bmi(weight, height):
    bmi = weight / (height ** 2)
    return bmi

weight = float(input("Enter your weight in kilograms:"))
height = float(input("Enter your height in meters:"))

bmi = calculate_bmi(weight, height)
print("Your BMI is:", bmi)
# Out:
# Enter your weight in kilograms:58
# Enter your height in meters:1.62
# Your BMI is: 22.10028959000152
